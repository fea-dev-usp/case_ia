# %% [markdown]
# # Lista de Exercícios: Case IA

# %% [markdown]
# Bem-vindos à lista de exercícios que acompanha o case de IA!\
#
# 🚨 Um pequeno disclaimer antes de iniciarmos: **essa lista pode conter erros**. Caso encontre um erro, por favor, traga o problema encontrado à algum membro da gerência da área de tecnologia para discutirmos e corrigirmos!
#
# A entrega dessa lista de exercícios deverá ser feita pelo seu próprio github, prestem atenção para não tentarem alterar o original!\
# ⚠ Assim, o primeiro passo é a **clonagem e/ou atualização do repositório**. ⚠

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **01.** Você trabalha em uma empresa de biotecnologia, e está atualmente criando um modelo para um projeto: o objetivo é criar um sistema que auxilia os pesquisadores e agiliza o processo de identificação das espécies das amostras de plantas trazidas ao laboratório.\
#     Para criar esse modelo, você recebe um banco de dados com diversas imagens de plantas, já rotuladas pelos pesquisadores especialistas.
#
# **a.** Partindo de seus conhecimentos sobre plantas, cite algumas características que poderiam ser coletadas pelo modelo a partir das fotos.\
# **b.** O modelo que você deve desenvolver é supervisionado ou não supervisionado? Por que?\
# **c.** Quais são alguns dos modelos de aprendizado de máquina que você poderia utilizar nesse projeto?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **02.** Você continua trabalhando na empresa de biotecnologia, mas agora está participando de um novo projeto: auxiliar os pesquisadores a classificarem plantas recém descobertas em uma pesquisa de campo. Desta vez, não há rótulos ou identificações fornecidas pelos especialistas, apenas imagens brutas das folhas e flores coletadas em campo.\
#     O objetivo do projeto é agrupar automaticamente essas plantas com base em suas semelhanças visuais.\
#     Assim, você e os pesquisadores podem investigar se as novas amostras correspondem a espécies novas ou variações de espécies já conhecidas.
#
# **a.** Descreva, em suas palavras, o objetivo principal desse tipo de modelo: o que ele deve tentar fazer com as imagens das plantas?\
# **b.** Quais são alguns dos modelos de aprendizado de máquina que você poderia utilizar nesse projeto?\
# **c.** Explique como o resultado final desse modelo poderia auxiliar os pesquisadores humanos para além de apenas sugerir o agrupamento das plantas.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **03.** Em um sistema de previsão agrícola, um modelo de aprendizado de máquina recebe como entrada diversas informações sobre o solo e o clima, como umidade, temperatura, índice de nutrientes e chuva acumulada, e deve prever a produtividade esperada da plantação.\
#     Sabemos que esse processo pode ser representado matematicamente como f: xi ∈ X → Y
#
# **a.** Seguindo as informações do enunciado, quais dados estão sendo representados por xi? E quanto ao Y?\
# **b.** Sabendo que o objetivo é prever um valor numérico de produtividade (em toneladas por hectare), qual tipo de tarefa de aprendizado supervisionado está sendo realizado: Classificação, regressão ou clusterização?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **04.** Depois de coletar muita informação e treinar o seu modelo com milhares de linhas com informações coletadas dentro do seu terreno e dos terrenos dos seus vizinhos dentro de um período de dois meses, o modelo de previsão agrícola funciona muito bem. Ele prevê a resposta do seu conjunto de teste com uma acurácia acima de 90%.\
#     Satisfeito com os resultados, você finalmente colocou seu sistema de previsão agrícola em funcionamento, juntamente com a chegada da nova estação.
#
# **a.** O modelo vai continuar apresentando a acurácia de +90% em todas as estações do ano? Qual é o problema identificado?\
# **b.** Por que o fato de o conjunto de treinamento ser pouco diverso pode causar esse problema?\
# **c.** Cite duas estratégias que poderiam ser adotadas para tentar corrigir ou reduzir o problema identificado.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **05.**
# Um grupo de analistas está desenvolvendo um modelo para prever o preço de venda de frutas em mercados regionais.\
# Eles testaram dois modelos diferentes:
#
# Modelo A: Um modelo simples, com poucas variáveis e uma função linear.\
# Modelo B: Um modelo muito complexo, que utiliza centenas de parâmetros e ajusta curvas detalhadas a cada ponto dos dados.
#
# Após os testes:
#
# O Modelo A teve erros altos tanto nos dados de treino quanto nos de teste.\
# O Modelo B teve erros quase nulos nos dados de treino, mas desempenho ruim nos dados de teste.
#
# Os analistas precisam decidir qual modelo ajustar e como encontrar um equilíbrio entre precisão e capacidade de generalização.
#
# **a.** Explique o que significa o modelo “ter viés alto” e qual dos dois modelos apresenta esse problema.\
# **b.** Faça o mesmo para a variância.\
# **c.** Por que não é possível simplesmente eliminar tanto o viés quanto o tradeoff completamente?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **06.** Você trabalha no departamento de tecnologia de um hospital de renome e sua equipe está desenvolvendo um modelo de machine learning para auxiliar médicos no diagnóstico precoce de uma doença rara e agressiva. \
# O objetivo é criar um sistema que analise exames de imagem e dados clínicos dos pacientes para sinalizar casos com alta probabilidade da doença.\
# Você recebe um conjunto de dados históricos de 10.000 pacientes. Desses, apenas 100 (1%) foram de fato diagnosticados com a doença, enquanto os outros 9.900 (99%) eram saudáveis.\
# Após treinar seu modelo, você o avalia em um conjunto de teste e alcança uma acurácia de 98%. Você considera o resultado um sucesso, afinal, o modelo parece acertar na grande maioria dos casos.
#
# **a.** Explique de forma simples o que caracteriza este projeto como um problema de classificação. O que o seu modelo, como um classificador, está tentando fazer com os dados de cada paciente?\
# **b.** Por que a métrica de acurácia de 98% pode ser extremamente enganosa e perigosa neste cenário específico? Descreva um "modelo inútil" que também poderia atingir essa mesma acurácia de 98% com este conjunto de dados.\
# **c.** "O custo dos erros são muito diferentes: se o modelo errar e não sinalizar um paciente doente (um falso negativo), a consequência é gravíssima, mas se ele sinalizar um paciente saudável como doente (um falso positivo), o custo é apenas um exame de confirmação". Qual outra métrica de avaliação seria muito importante de se calcular? Justifique.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **07.** Você foi contratado por uma grande plataforma online de venda de carros usados. A empresa quer oferecer uma nova ferramenta para seus usuários: um "Avaliador de Preço Inteligente". O objetivo é que um vendedor possa inserir as características do seu carro e o sistema sugira um preço de venda justo e competitivo, com base em milhares de anúncios e vendas já realizadas na plataforma.\
#     Sua tarefa é desenvolver o modelo de Machine Learning que será o coração dessa ferramenta. Você recebe um conjunto de dados que contém as seguintes informações sobre cada carro vendido:
#
# |Features|
# |---|
# |Marca e modelo do carro|
# |Ano de fabricação|
# |Quilometragem rodada|
# |Potência do motor (em cavalos)|
# |Tipo de câmbio (manual ou automático)|
# |Preço final de venda|
#
# **a.** Este é um problema de regressão ou de classificação? Justifique sua resposta, explicando qual é a principal diferença entre o que o modelo precisa prever aqui e o que o modelo do caso anterior previa.\
# **b.** Após treinar o modelo, você precisa medir o quão "bom" ele é. Faria sentido usar a métrica Acurácia para avaliar este modelo de previsão de preços? Por que?\
# **c.** Cite uma métrica que pode ser utilizada para avaliar o modelo e por que ela é apropriada.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **08.** Com o objetivo de melhorar a performance da ferramenta, você decide inserir mais características dos carros dentro do modelo. Você decide colocar as seguintes informações:
#
# |Features|
# |---|
# |    Marca e modelo do carro|
# |    Fabricante|
# |    País de origem|
# |    Ano de fabricação|
# |    Mês de fabricação|
# |    Semestre de fabricação|
# |    Idade do carro|
# |    Tipo sanguíneo do primeiro dono|
# |    Quilometragem rodada|
# |    Quilometragem rodada (em metros)|
# |    Potência do motor (em cavalos)|
# |    Tipo de motor|
# |    Velocidade máxima|
# |    Tipo de câmbio (manual ou automático)|
# |    Cor do carro|
# |    Cor original do carro|
# |    Preço final de venda|
#
# **a.** Por que a adição de mais informações pode não representar melhor performance do modelo?\
# **b.** Quais features irão atrapalhar mais do que ajudar o modelo?\
# **c.** Como podemos reduzir o impacto das diferentes ordens de magnitude entre algumas features numéricas (ex: preço, quilometragem e potência do motor)?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **09.** Você está construindo um modelo KNN para um projeto, que busca prever a faixa salarial de pessoas aleatórias com as seguintes informações:
#
# |Features|
# |---|
# |Data de nascimento (datetime)|
# |Educação (object)|
# |Anos na escola (int)|
# |Tipo de trabalho (object)|
# |Gênero (object)|
# |Etnia (object)|
# |Horas de trabalho (int)|
# |Salário (object)|
#
# Explorando o seu dataset, você descobre que existem dados faltantes, outliers e altas correlações.\
# Você também sabe que seu modelo de KNN aceita apenas features numéricas.
#
# **a.** Quais etapas de processamento de dados podemos utilizar para corrigir os problemas encontrados?\
# **b.** Como podemos melhorar a feature "Data de nascimento" para que a informação seja mais enxuta?\
# **c.** Cite um método que possa ser utilizado para transformar as features categóticas em features numéricas e explique brevemente seu funcionamento.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **10.** O classificador de Bayes é conhecido também como o "classificador ótimo", pois é aquele que apresenta menor probabilidade de erro.
#
# **a.** Por que ele é um modelo puramente teórico? Explique utilizando a diferença entre probabilidade e probabilidade empírica \
# **b.** O que são classificadores Plug-In?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **11.** Você trabalha como cientista de dados em uma empresa imobiliária que deseja estimar o preço de venda de casas com base em suas características.\
# O banco de dados contém variáveis como:
#
# |Variáveis|
# |-|
# |tamanho da casa (m²)|
# |número de quartos|
# |idade do imóvel|
# |localização (coordenadas)|
#
# O modelo treinado será usado para prever o preço (em reais) de casas novas que ainda não foram colocadas à venda.
#
# **a.** Esse é um problema de classificação ou de regressão? Justifique.\
# **b.** Durante os testes, o modelo apresentou as seguintes métricas:
# |Métricas|
# |-|
# |MSE = 2.500.000|
# |RMSE = 1.581|
# |MAE = 1.200|
# |R² = 0.85|
#
# Interprete esses valores:\
# **b1.** O que significa, na prática, o MAE ser 1.200?\
# **b2.** O que indica o valor de R² = 0.85?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **12.** Você desenvolveu um modelo de regressão para prever a produção anual de soja (em toneladas) com base em dados climáticos.
#
# Os resultados mostram que, em média, o modelo tem R² = 0.65 e RMSE = 400 toneladas.
#
# Um colega propõe usar um modelo mais simples, que apresenta R² = 0.60, mas RMSE = 320 toneladas.
#
# **a.** Explique o que cada métrica está indicando sobre os modelos.\
# **b.** Qual modelo você escolheria, e por quê? Leve em consideração o equilíbrio entre precisão e explicabilidade.\
# **c.** O que poderia ser feito para melhorar o desempenho geral do modelo sem aumentar a chance de overfitting?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **13.** Uma equipe de cientistas de dados está desenvolvendo um modelo para classificar exames médicos como "Normal" ou "Alterado", com base em medidas obtidas por sensores de imagem e pressão arterial.
#
# Por se tratar de um problema em que as fronteiras entre as classes são não lineares e os dados são difíceis de generalizar, a equipe decide testar o algoritmo K-Nearest Neighbors (KNN).
#
# Durante os testes, observam o seguinte comportamento:
#
# | K | Acurácia (treino) | Acurácia (teste) |
# | - | ----------------- | ---------------- |
# | 1 | 100%              | 72%              |
# | 3 | 94%               | 80%              |
# | 5 | 90%               | 82%              |
# | 9 | 85%               | 75%              |
#
# **a.** Explique, com base no comportamento da tabela, o que está acontecendo com o modelo quando K = 1 e quando K aumenta. Qual fenômeno está sendo observado aqui, em termos de fit?\
# **b.** Como o parâmetro K atua no controle do trade-off entre bias e variância?\
# **c.** Por que o KNN é sensível à escala das variáveis? Descreva uma técnica de pré-processamento essencial para evitar distorções nesse tipo de modelo.\
# **d.** Suponha que as variáveis incluam tanto idade (em anos) quanto nível de glicose (em mg/dL). Se uma das variáveis for muito maior em magnitude, o que acontecerá com o cálculo da distância entre vizinhos?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **14.** Uma empresa de tecnologia deseja criar um filtro de spam.\
# Cada e-mail é representado por um vetor de características binárias indicando a presença ou ausência de certas palavras (ex.: “promoção”, “grátis”, “urgente”, “clique”).\
# O time decide usar o classificador Naive Bayes Multinomial, por sua eficiência e boa performance em texto.
#
# Durante o treinamento, obtém-se as seguintes probabilidades:
#
# | Palavra | P(palavra dado spam) | P(palavra dado não spam) |
# |----------|-------------|----------------|
# | promoção | 0.30 | 0.02 |
# | clique | 0.20 | 0.01 |
# | urgente | 0.25 | 0.05 |
#
# *** "palavra dado spam" = P(palavra|spam) em probabilidade condicional
#
# Um novo e-mail chega com as palavras “promoção” e “urgente”.\
# Sabemos ainda que:
#
# P(spam) = 0.4\
# P(não spam) = 0.6
#
# **a.** Calcule, sem normalizar, as probabilidades proporcionais de o e-mail ser spam ou não, usando o modelo de independência condicional do Naive Bayes.\
# **b.** Qual das duas classes o modelo escolheria?\
# **c.** Explique o significado da palavra “Naive” no nome do algoritmo e por que essa suposição é, ao mesmo tempo, uma limitação e uma vantagem prática?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **15.** Uma empresa de tecnologia educacional está criando um modelo para prever se um aluno concluirá um curso online (variável-alvo: 1 = conclui, 0 = não conclui).
#
# As variáveis usadas no modelo são:
# | Variável             | Descrição                                      |
# | -------------------- | ---------------------------------------------- |
# | `tempo_medio_estudo` | horas médias de estudo por semana              |
# | `participacao_forum` | número médio de interações no fórum por semana |
# | `atraso_entregas`    | proporção de tarefas entregues com atraso      |
#
# Após o treinamento, o modelo de Regressão Logística produziu os seguintes coeficientes:
#
# | Variável           | Coeficiente (β) |
# | ------------------ | --------------- |
# | Intercepto         | -2.0            |
# | tempo_medio_estudo | 0.8             |
# | participacao_forum | 0.3             |
# | atraso_entregas    | -1.5            |
#
# **a.** Qual é o sinal (positivo ou negativo) da relação entre cada variável e a probabilidade de o aluno concluir o curso? Explique o significado intuitivo de cada coeficiente.\
# **b.** Sabendo que a função logística é
#
# $$P(y=1) = \frac{1}{1 + e ^{(B0 + B1x1+...)}}$$
#
# Calcule a probabilidade estimada de um aluno que:
#
# * estuda 3 horas por semana
# * participa 4 vezes no fórum
# * atrasa 20% das entregas
#
# **c.** Explique o que significa o coeficiente 0.8 do tempo_medio_estudo em termos de razão de chances (odds ratio). Qual o efeito aproximado de aumentar uma hora de estudo por semana, mantendo as outras variáveis fixas?\
# **d.** Como você avaliaria o desempenho desse modelo em um conjunto de teste? Cite duas métricas apropriadas e explique brevemente por que são úteis para esse tipo de problema.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **16.** Uma equipe de cientistas de dados está criando um modelo para classificar tipos de flores com base em duas medidas: largura_da_pétala e comprimento_da_pétala.
#
# Ao visualizar os dados, percebem que as classes não são separáveis por uma linha reta e decidem testar o Support Vector Classifier (SVC) com diferentes funções kernel.
#
# | Tipo de Kernel              | Característica                                                |
# | --------------------------- | ------------------------------------------------------------- |
# | Linear                      | cria fronteiras planas (hiperplanos)                          |
# | Polinomial                  | permite curvas polinomiais de grau escolhido                  |
# | RBF (Radial Basis Function) | cria fronteiras flexíveis baseadas em distâncias (gaussianas) |
#
# Durante o experimento, observam que:
#
# * O kernel linear separa apenas parte das flores corretamente.
# * O kernel polinomial de grau 3 melhora o resultado, mas ainda erra casos nos extremos.
# * O kernel RBF obtém quase 100% de acerto no treino, mas perde desempenho no teste.
#
# **a.** Explique, de forma conceitual, o que o SVC tenta fazer ao classificar os dados. O que representa a margem máxima e por que ela é importante?\
# **b.** Qual o papel da função kernel no SVC? Por que ela é útil em dados não linearmente separáveis?\
# **c.** Com base nos resultados, o que provavelmente está acontecendo com o modelo ao usar o kernel RBF? Qual conceito de generalização está sendo afetado?\
# **d.** Se fosse necessário ajustar o modelo com kernel RBF, cite dois parâmetros importantes que você deveria calibrar e explique o impacto de cada um deles.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **17.** Uma empresa de telecomunicações está desenvolvendo um modelo para prever se um cliente cancelará o plano (churn).\
# Eles utilizaram um modelo de árvore de decisão com as variáveis:\
# idade, tempo_de_contrato, gasto_mensal, reclamações_no_suporte.
#
# Durante o treinamento, testaram diferentes configurações de profundidade máxima e critérios de divisão:
#
# | Profundidade Máx | Critério | Acurácia (Treino) | Acurácia (Teste) |
# | ---------------- | -------- | ----------------- | ---------------- |
# | 10               | Gini     | 99%               | 72%              |
# | 5                | Entropia | 91%               | 86%              |
# | 3                | Gini     | 88%               | 84%              |
#
# **a.** Explique o que significa o critério Gini e o critério de entropia. Qual deles tende a gerar divisões mais “puras”?\
# **b.** Com base na tabela, o que está acontecendo com a árvore de profundidade 10? Qual fenômeno clássico de modelagem esse resultado representa?\
# **c.** Como a poda (pruning) pode ajudar a resolver o problema identificado acima? Cite um tipo de poda usada em modelos de árvore.\
# **d.** Explique, conceitualmente, a diferença entre usar uma árvore muito profunda e uma muito rasa em termos de viés e variância.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **18.** Um time de cientistas de dados está competindo em um hackathon de classificação de imagens.\
# Após testar árvores de decisão simples, decidem explorar técnicas de ensemble para melhorar o desempenho.
#
# Os resultados médios em validação cruzada foram:
#
# | Modelo                    | Acurácia | Observações                            |
# | ------------------------- | -------- | -------------------------------------- |
# | Árvore de decisão (base)  | 81%      | Simples, instável                      |
# | Random Forest             | 88%      | Média de várias árvores                |
# | AdaBoost                  | 90%      | Corrige erros iterativamente           |
# | Gradient Boosting         | 92%      | Ajusta gradualmente o erro residual    |
# | XGBoost                   | 93%      | Otimização regularizada                |
# | Stacking (RF + XGB + SVC) | 94%      | Combina predições de múltiplos modelos |
#
# **a.** Explique a diferença conceitual entre bagging e boosting. Como cada abordagem reduz o erro de generalização?\
# **b.** O que é o modelo base usado em bagging e boosting? Por que geralmente se usa árvores fracas nesses casos?\
# **c.** Entre AdaBoost e Gradient Boosting, qual trabalha explicitamente com resíduos do modelo anterior e como isso afeta o processo de aprendizado?\
# **d.** Por que o XGBoost costuma ter desempenho superior aos modelos clássicos de boosting? Cite duas características técnicas que o tornam mais eficiente.\
# **e.** Explique o funcionamento conceitual do Stacking. Por que essa técnica pode superar individualmente os modelos de ensemble que a compõem?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **19.** Uma empresa biomédica coleta dados de exames de sangue para classificar pacientes em “Saudável” ou “Doente”, usando duas variáveis principais:
# nível_de_hemoglobina e nível_de_glicose.
#
# Duas abordagens são testadas:
# * LDA (Linear Discriminant Analysis)
# * QDA (Quadratic Discriminant Analysis)
#
# Após avaliar em validação cruzada, obtêm-se os seguintes resultados:
#
# | Modelo | Acurácia | Desvio Padrão | Observações                      |
# | ------ | -------- | ------------- | -------------------------------- |
# | LDA    | 89%      | 2%            | Fronteira linear                 |
# | QDA    | 91%      | 6%            | Fronteira curvada, mais flexível |
#
# **a.** Qual é a principal diferença matemática entre LDA e QDA em relação às matrizes de covariância das classes?\
# **b.** Por que o QDA tende a se ajustar melhor a dados não linearmente separáveis, mas também pode ter maior variância?\
# **c.** O que significa o desvio padrão maior do QDA na tabela? Como isso se relaciona com o conceito de estabilidade do modelo?\
# **d.** Se o conjunto de dados for pequeno e as classes tiverem amostras desbalanceadas, qual modelo é mais indicado? Justifique com base nas suposições de cada um.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **20.** Um economista está estudando a relação entre o salário médio em reais e os anos de experiência profissional de trabalhadores em uma empresa.\
# Ele ajusta o modelo de regressão linear simples:
#
# $${Salário = 1500 + 900 * Anos de experiência}$$
#
# O R² obtido foi 0,78.
#
# **a.** Interprete os coeficientes da regressão. O que significam o intercepto (1500) e o coeficiente angular (900)?\
# **b.** O que o valor de R² = 0,78 indica sobre o ajuste do modelo?\
# **c.** Explique duas suposições básicas da regressão linear que, se violadas, podem tornar esse modelo inadequado.\
# **d.** Se os dados apresentarem relação não linear, qual tipo de transformação poderia ser aplicada antes de reestimar o modelo?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **21.** Um analista financeiro desenvolve um modelo para prever o preço de imóveis (em R$) a partir de três variáveis:
#
# |Variáveis|
# |---|
# |tamanho (m²)|
# |número_de_quartos|
# |distância_centro (km)|
#
# O modelo obtido foi:
#
# $${Preço = 20000 + 4000 * tamanho + 12000 * quartos - 3000 * distância}$$
#
# O analista percebe, no entanto, que tamanho e quartos estão altamente correlacionados.
#
# **a.** Interprete o sinal e a magnitude de cada coeficiente.\
# **b.** O que é multicolinearidade e como ela pode afetar a confiabilidade desse modelo?\
# **c.** Cite uma técnica que pode ser usada para detectar multicolinearidade.\
# **d.** Como a multicolinearidade poderia ser mitigada ou corrigida sem descartar variáveis importantes?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **22.** Uma empresa de marketing tenta prever as vendas semanais com base em 15 variáveis (publicidade, clima, preço, sazonalidade, etc.).\
# O modelo linear comum apresentou overfitting, com R² = 0.95 no treino e 0.62 no teste.\
# A equipe decide testar Ridge e Lasso Regression.
#
# **a.** Explique, conceitualmente, como Ridge e Lasso combatem o overfitting.\
# **b.** Qual é o papel do parâmetro λ (alpha) nesses modelos? Se o λ for muito grande, o que acontecerá com o modelo?\
# **c.** Qual a diferença principal entre o efeito de Lasso e Ridge sobre os coeficientes?\
# **d.** Quando você escolheria Lasso em vez de Ridge?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **23.** Uma montadora usa SVR para prever o consumo de combustível (km/L) de carros, com base em:
# * peso
# * cilindrada
# * potência
# * aerodinâmica
#
# Após os testes, os seguintes resultados foram observados:
# | Kernel | C   | ε (epsilon) | R² (teste) |
# | ------ | --- | ----------- | ---------- |
# | Linear | 1   | 0.1         | 0.76       |
# | RBF    | 10  | 0.2         | 0.85       |
# | RBF    | 100 | 0.01        | 0.68       |
#
# **a.** Explique, de forma conceitual, como o SVR se diferencia de uma regressão linear comum.\
# **b.** O que significa o parâmetro ε (epsilon) e como ele afeta o ajuste do modelo?\
# **c.** Como o parâmetro C influencia o equilíbrio entre bias e variância?\
# **d.** Analise a tabela: o que pode ter causado a queda no desempenho com C = 100 e ε = 0.01?\
# **e.** Em que tipo de relação entre variáveis o kernel RBF é mais vantajoso do que o kernel linear?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **24.** Uma fazenda inteligente usa uma árvore de regressão para prever a produção de soja (em toneladas) com base em variáveis climáticas:
# * chuva
# * temperatura
# * radiação solar
# * umidade
#
# Durante os testes, a equipe analisou dois critérios de divisão:
# | Critério | Profundidade Máx | MSE (teste) | MAE (teste) |
# | -------- | ---------------- | ----------- | ----------- |
# | MSE      | 10               | 15.2        | 3.6         |
# | MAE      | 5                | 16.0        | 3.8         |
#
# **a.** Explique a diferença conceitual entre usar MSE e MAE como critério de divisão. Qual tende a ser mais sensível a outliers?\
# **b.** O que está acontecendo com a árvore de profundidade 10? Que tipo de problema está sendo observado?\
# **c.** Como a poda (pruning) ajuda a corrigir o problema acima?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **25.** Um analista de dados tenta prever o lucro mensal de lojas.\
# Modelos simples (árvores únicas) mostraram alta variância, então ele testou técnicas de ensemble:
#
# | Modelo                       | R² (treino) | R² (teste) | Observação                  |
# | ---------------------------- | ----------- | ---------- | --------------------------- |
# | Árvore única                 | 0.96        | 0.72       | Overfitting                 |
# | Random Forest (Bagging)      | 0.92        | 0.86       | Mais estável                |
# | AdaBoost                     | 0.94        | 0.88       | Corrige erros gradualmente  |
# | Gradient Boosting            | 0.96        | 0.90       | Ajuste sobre resíduos       |
# | Stochastic Gradient Boosting | 0.95        | 0.91       | Subamostragem aleatória     |
# | XGBoost                      | 0.97        | 0.93       | Regularização e paralelismo |
#
# **a.** Explique o princípio básico do bagging. Por que ele reduz a variância do modelo?\
# **b.** O que diferencia o boosting do bagging em termos de aprendizado e sequência de modelos?\
# **c.** Por que o Stochastic Gradient Boosting tende a generalizar melhor do que o Gradient Boosting puro?\
# **d.** Quais características técnicas fazem do XGBoost uma evolução do Gradient Boosting tradicional?

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
